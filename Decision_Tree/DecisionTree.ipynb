# %% [markdown]
# # Decision Trees 决策树

# %% [markdown]
# ### 1. Entropy 熵
# #### 熵公式推导
# * 计算取出结果与原顺序相同的概率：$P=P_1\times P_2 \times...\times P_n$
# * 将概率公式取以2为底的对数变换：$log_2(P)=log_2(P_1)+log_2(P_2)+...+log_2(P_n)$
# * 熵公式 $Entropy=\frac{1}{n}log_2(P)$
# ![Screen%20Shot%202019-07-22%20at%2010.42.33.png](attachment:Screen%20Shot%202019-07-22%20at%2010.42.33.png)
# ![image.png](attachment:image.png)@w=450
